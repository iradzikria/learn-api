# %%
import pandas as pd

# Import library for Flask
from flask import Flask, jsonify, request
from flasgger import Swagger, LazyString, LazyJSONEncoder
from flasgger import swag_from


# Define Swagger UI description
app = Flask(__name__)
app.json_encoder = LazyJSONEncoder
swagger_template = dict(
info = {
    'title': LazyString(lambda: 'API Documentation for Data Processing and Modeling'),
    'version': LazyString(lambda: '1.0.0'),
    'description': LazyString(lambda: 'Dokumentasi API untuk Data Processing dan Modeling'),
    },
    host = LazyString(lambda: request.host)
)
swagger_config = {
    "headers": [],
    "specs": [
        {
            "endpoint": 'docs',
            "route": '/docs.json',
        }
    ],
    "static_url_path": "/flasgger_static",
    "swagger_ui": True,
    "specs_route": "/docs/"
}
swagger = Swagger(app, template=swagger_template,             
                  config=swagger_config)

# Define endpoint for "input teks via form"
@swag_from("docs/hello_world.yml", methods=['GET'])
@app.route('/', methods=['GET'])
def hello_world():
    json_response = {
        'status_code': 200,
        'description': "Menyapa Hello World",
        'data': "Hello World",
    }
    response_data = jsonify(json_response)
    return response_data

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [01/Sep/2023 20:41:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Sep/2023 20:41:26] "GET /apidocs HTTP/1.1" 404 -
# 127.0.0.1 - - [01/Sep/2023 20:41:39] "GET /docs/ HTTP/1.1" 200 -
# ERROR:root:jsonify failure; defaulting to json.dumps
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 581, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 590, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 164, in get
#     return jsonify(self.loader())
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 438, in get_apispecs
#     specs = get_specs(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 180, in get_specs
#     doc_summary, doc_description, doc_swag = parse_docstring(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 646, in parse_docstring
#     full_doc = load_from_file(swag_paths[key], swag_type)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 604, in load_from_file
#     if package_spec.has_location:
# AttributeError: 'NoneType' object has no attribute 'has_location'
# ERROR:__main__:Exception on /docs.json [GET]
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 581, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 590, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 164, in get
#     return jsonify(self.loader())
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 438, in get_apispecs
#     specs = get_specs(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 180, in get_specs
#     doc_summary, doc_description, doc_swag = parse_docstring(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 646, in parse_docstring
#     full_doc = load_from_file(swag_paths[key], swag_type)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 604, in load_from_file
#     if package_spec.has_location:
# AttributeError: 'NoneType' object has no attribute 'has_location'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 581, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 590, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\views.py", line 89, in view
#     return self.dispatch_request(*args, **kwargs)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\views.py", line 163, in dispatch_request
#     return meth(*args, **kwargs)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 168, in get
#     specs = json.dumps(self.loader())
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 438, in get_apispecs
#     specs = get_specs(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 180, in get_specs
#     doc_summary, doc_description, doc_swag = parse_docstring(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 646, in parse_docstring
#     full_doc = load_from_file(swag_paths[key], swag_type)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 604, in load_from_file
#     if package_spec.has_location:
# AttributeError: 'NoneType' object has no attribute 'has_location'
# 127.0.0.1 - - [01/Sep/2023 20:41:40] "GET /docs.json HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [01/Sep/2023 20:41:40] "GET /docs.json HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Sep/2023 20:46:01] "GET /docs/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Sep/2023 20:46:01] "GET /docs/ HTTP/1.1" 200 -
# ERROR:root:jsonify failure; defaulting to json.dumps
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 581, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 590, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 164, in get
#     return jsonify(self.loader())
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 438, in get_apispecs
#     specs = get_specs(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 180, in get_specs
#     doc_summary, doc_description, doc_swag = parse_docstring(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 646, in parse_docstring
#     full_doc = load_from_file(swag_paths[key], swag_type)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 604, in load_from_file
#     if package_spec.has_location:
# AttributeError: 'NoneType' object has no attribute 'has_location'
# ERROR:__main__:Exception on /docs.json [GET]
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 581, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 590, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 164, in get
#     return jsonify(self.loader())
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 438, in get_apispecs
#     specs = get_specs(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 180, in get_specs
#     doc_summary, doc_description, doc_swag = parse_docstring(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 646, in parse_docstring
#     full_doc = load_from_file(swag_paths[key], swag_type)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 604, in load_from_file
#     if package_spec.has_location:
# AttributeError: 'NoneType' object has no attribute 'has_location'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 581, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 590, in load_from_file
#     enc = detect_by_bom(swag_path)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 616, in detect_by_bom
#     with open(path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iradz\\AppData\\Local\\Temp\\ipykernel_29484\\docs/hello_world.yml'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\views.py", line 89, in view
#     return self.dispatch_request(*args, **kwargs)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flask\views.py", line 163, in dispatch_request
#     return meth(*args, **kwargs)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 168, in get
#     specs = json.dumps(self.loader())
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\base.py", line 438, in get_apispecs
#     specs = get_specs(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 180, in get_specs
#     doc_summary, doc_description, doc_swag = parse_docstring(
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 646, in parse_docstring
#     full_doc = load_from_file(swag_paths[key], swag_type)
#   File "C:\Users\iradz\anaconda3\lib\site-packages\flasgger\utils.py", line 604, in load_from_file
#     if package_spec.has_location:
# AttributeError: 'NoneType' object has no attribute 'has_location'
# 127.0.0.1 - - [01/Sep/2023 20:46:01] "GET /docs.json HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [01/Sep/2023 20:46:01] "GET /docs.json HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Sep/2023 20:46:01] "GET /flasgger_static/favicon-32x32.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Sep/2023 20:46:01] "GET /flasgger_static/favicon-32x32.png HTTP/1.1" 200 -

# %%
import flasgger
flasgger.__version__
# Out:
# '0.9.7b2'

# %%
import flask
flask.__version__
# Out:
# '1.1.2'
